# %% [markdown]
# ## **Task1 - Iris Flower Classification**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv('https://raw.githubusercontent.com/info-aidtech/Iris-Flower-Classification-Dataset/e06cecde7c4ef91abdbc5b82751eeae12bb16412/IRIS.csv', header=0)
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
X=iris_data.drop('species', axis=1)
y=iris_data['species']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42, test_size=0.25)

# %%
iris_data.skew()
# Out:
# <ipython-input-35-7bbca58ffefc>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.skew()
# sepal_length    0.314911
# sepal_width     0.334053
# petal_length   -0.274464
# petal_width    -0.104997
# dtype: float64

# %%
#Skewness plot
sns.distplot(iris_data.skew(), color="red", axlabel="Skewness")
# Out:
# <ipython-input-36-2264c9f84c24>:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.distplot(iris_data.skew(), color="red", axlabel="Skewness")
# <ipython-input-36-2264c9f84c24>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris_data.skew(), color="red", axlabel="Skewness")
# <Axes: xlabel='Skewness', ylabel='Density'>

# %%
iris_data.kurt()
# Out:
# <ipython-input-37-7fd0d36ad6c3>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.kurt()
# sepal_length   -0.552064
# sepal_width     0.290781
# petal_length   -1.401921
# petal_width    -1.339754
# dtype: float64

# %%
sns.distplot(iris_data.kurt(), color="red", axlabel="Kurtosis")
# Out:
# <ipython-input-38-74cbf0852a9d>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.distplot(iris_data.kurt(), color="red", axlabel="Kurtosis")
# <ipython-input-38-74cbf0852a9d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris_data.kurt(), color="red", axlabel="Kurtosis")
# <Axes: xlabel='Kurtosis', ylabel='Density'>

# %%
#Histogram of target variable
plt.figure(figsize=(8,6))
plt.xlabel("Iris flower type", fontsize=10)
plt.ylabel("Frequency", fontsize=10)
plt.hist(iris_data['species'], color="blue")
plt.show()

# %%
# Boxplot of sepal_length and species
plt.figure(figsize=(6,4))
sns.boxplot(y="sepal_length", x="species", data= iris_data)
plt.title("sepal_length vs species", fontsize=15)
plt.xlabel("sepal_length", fontsize=15)
plt.ylabel("species", fontsize=15)
plt.show()

# %%
# Boxplot of sepal_width and species
plt.figure(figsize=(6,4))
sns.boxplot(y="sepal_width", x="species", data= iris_data)
plt.title("sepal_width vs species", fontsize=15)
plt.xlabel("sepal_width", fontsize=15)
plt.ylabel("species", fontsize=15)
plt.show()

# %%
# Boxplot of petal_length and species
plt.figure(figsize=(6,4))
sns.boxplot(y="petal_length", x="species", data= iris_data)
plt.title("petal_length vs species", fontsize=15)
plt.xlabel("petal_length", fontsize=15)
plt.ylabel("species", fontsize=15)
plt.show()

# %%
correlation = iris_data.corr(numeric_only="silence")
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(iris_data[["sepal_length","sepal_width","petal_length","petal_width"]].corr(), square=True, annot=True, cmap = 'Reds')
# Out:
# <Axes: >

# %%
for i in iris_data.columns:
  if i!="species":
    plt.ylabel(i)
    plt.scatter( iris_data["species"], iris_data[i])
    plt.show()

# %% [markdown]
# # **Decision Tree Classfier**

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)

print("Score of Test data is:",dt.score(X_test,y_test))
# Out:
# Score of Test data is: 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt

fig, axis = plt.subplots(figsize=(10,8))
tree.plot_tree(dt, feature_names=X.columns, class_names=y.unique(), filled=True, ax=axis)
plt.show()

# %%
dt.predict(X_test)
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
# Lets shuffle values in columns and try, this become new data
from random import shuffle

sepal_length = list(iris_data["sepal_length"])
shuffle(sepal_length)

sepal_width = list(iris_data["sepal_width"])
shuffle(sepal_width)

petal_length = list(iris_data["petal_length"])
shuffle(petal_length)

petal_width = list(iris_data["petal_width"])
shuffle(petal_width)

new_iris_data = pd.DataFrame({"sepal_length":sepal_length, "sepal_width":sepal_width, "petal_length":petal_length, "petal_width":petal_width})
new_iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.1           5.1          2.5
# 1           4.6          3.6           1.6          1.3
# 2           4.4          3.0           1.3          2.5
# 3           7.9          3.0           1.9          0.1
# 4           6.9          2.9           3.0          2.3

# %%
dt.predict(new_iris_data)
# Out:
# array(['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
# ...

# %%
def classify_iris_type(s_length,	s_width,	p_length,	p_width):
  test = {"sepal_length":[s_length],	"sepal_width":[s_width],	"petal_length":[p_length],	"petal_width":[p_width]}
  pred = dt.predict(pd.DataFrame(test))
  print("Iris type is:", pred[0])

# %%
go=1
while(go==1):
  sl=float(input("Enter sepal_length: "))
  sw=float(input("Enter sepal_width: "))
  pl=float(input("Enter petal_length: "))
  pw=float(input("Enter petal_width: "))
  classify_iris_type(sl, sw, pl, pw)
  go=int(input("Want to cont ?(0/1): "))
# Out:
# Enter sepal_length: 2.3
# Enter sepal_width: 2.6
# Enter petal_length: 9.3
# Enter petal_width: 0.5
# Iris type is: Iris-virginica
# Want to cont ?(0/1): 0

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1, metric='minkowski', p=2 )
knn.fit(X_train, y_train)
print("Score using KNN is:",knn.score(X_test,y_test))
# Out:
# Score using KNN is: 1.0
